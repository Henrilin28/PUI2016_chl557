# %%
import pandas as pd
import os

# %%
file_path = os.getenv("DFDATA")+"/wng2-85mv/1414246045/wng2-85mv"

dataframe = pd.read_csv(file_path,na_values=" NaN")
dataframe = dataframe.dropna(axis=0)

# %%
top_10_frame = dataframe.head(10)
top_10_frame
# Out:
#     ID  GIS ID  Roadway Name         From                To Direction  \
# 0    1   15540  BEACH STREET  UNION PLACE  VAN DUZER STREET        NB
# 1    2   15540  BEACH STREET  UNION PLACE  VAN DUZER STREET        NB
# 2    3   15540  BEACH STREET  UNION PLACE  VAN DUZER STREET        NB
# 3    4   15540  BEACH STREET  UNION PLACE  VAN DUZER STREET        NB
# 4    5   15540  BEACH STREET  UNION PLACE  VAN DUZER STREET        NB
# 6    7   15540  BEACH STREET  UNION PLACE  VAN DUZER STREET        SB
# 7    8   15540  BEACH STREET  UNION PLACE  VAN DUZER STREET        SB
# 8    9   15540  BEACH STREET  UNION PLACE  VAN DUZER STREET        SB
# 9   10   15540  BEACH STREET  UNION PLACE  VAN DUZER STREET        SB
# 10  11   15540  BEACH STREET  UNION PLACE  VAN DUZER STREET        SB
#
#           Date  12:00-1:00 AM  1:00-2:00AM  2:00-3:00AM      ...        \
# 0   01/09/2012             20           10           11      ...
# ...

# %%
numeric_frame = top_10_frame._get_numeric_data()
numeric_frame
# Out:
#     ID  GIS ID  12:00-1:00 AM  1:00-2:00AM  2:00-3:00AM  3:00-4:00AM  \
# 0    1   15540             20           10           11           14
# 1    2   15540             21           16            8            6
# 2    3   15540             27           14            6            5
# 3    4   15540             22            7            7            8
# 4    5   15540             31           17            7            5
# 6    7   15540             27           12           12            4
# 7    8   15540             26           16           11           13
# 8    9   15540             32           16            8            9
# 9   10   15540             24           12            7           18
# 10  11   15540             39           22            8            6
#
#     4:00-5:00AM  5:00-6:00AM  6:00-7:00AM  7:00-8:00AM      ...        \
# 0            13           20           34           66      ...
# 1            13           13           31           70      ...
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib.colors as colors


fig = plt.figure(figsize=(13, 8), dpi=80)


numeric_frame.plot(x=numeric_frame.columns[2],y=numeric_frame.columns[3],
                   kind="scatter")
plt.legend(bbox_to_anchor=(1.05, 1),ncol=3, loc=2, borderaxespad=0.)
plt.title('Figure 1',fontsize=20)
plt.text(20,1,'scatter plot for different ',fontsize =20)
plt.xlabel(numeric_frame.columns[2],fontsize = 20)
plt.ylabel(numeric_frame.columns[3],fontsize = 20,rotation=90)
# Out:
# /opt/rh/anaconda/root/envs/PUI2016_Python3/lib/python3.5/site-packages/matplotlib/axes/_axes.py:519: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %% [markdown]
# ## Extra

# %%
temp  = numeric_frame.set_index("GIS ID")

# %%
extra_frame = dataframe._get_numeric_data()

# %%
temp = extra_frame.set_index("GIS ID")
temp = temp.drop("ID",1)

# %%
extra_file_path = os.getenv("DFDATA")+"/5b3a-rs48/1414245944/5b3a-rs48"

ex_df = pd.read_csv(extra_file_path,na_values=" NaN")
ex_df = ex_df.dropna(axis=0)
ex_df.head(10)
# Out:
#        Agency  Platform                                                Url  \
# 1         TLC  Facebook  http://www.facebook.com/pages/NYC-Taxi-and-Lim...
# 6        MOAE   YouTube                http://www.youtube.com/YouCanTooNYC
# 9        DSNY   YouTube              http://www.youtube.com/nycrecyclemore
# 10        DOH   Youtube          http://www.youtube.com/user/drinkingsugar
# 15       MOME   Android                                     MiNY Venor app
# 18      ENDHT  Facebook  http://www.facebook.com/pages/NYC-Lets-End-Hum...
# 19        VAC  Facebook  https://www.facebook.com/pages/NYC-Voter-Assis...
# 20     PlaNYC  Facebook  http://www.facebook.com/pages/New-York-NY/PlaN...
# 21       DFTA  Facebook  http://www.facebook.com/pages/NYC-Department-f...
# 22  energyNYC  Facebook          http://www.facebook.com/EnergyNYC?sk=wall
#
#               Date Sampled  Likes/Followers/Visits/Downloads
# 1   12/12/2012 12:00:00 AM                             505.0
# ...

# %%
temp = ex_df.drop("Url",1)
temp.index = pd.to_datetime(temp["Date Sampled"])

# %%
final = temp.drop("Date Sampled",1)

# %%
test  = ex_df.groupby('Platform')['Likes/Followers/Visits/Downloads'].apply(pd.value_counts).count(level=0)

# %%
test.plot(kind="bar")

# %%
facebook_viz = ex_df[ex_df["Platform"] == "Facebook"]

# %%
facebook_viz.index = pd.to_datetime(facebook_viz["Date Sampled"])
facebook_viz = facebook_viz.drop(["Platform","Url","Date Sampled"],1)

# %%
plt.figure()
for i, group in facebook_viz.groupby('Agency'):
    group.plot(x=group.index, y='Likes/Followers/Visits/Downloads', title=str(i),kind=)
# Out:
# /opt/rh/anaconda/root/envs/PUI2016_Python3/lib/python3.5/site-packages/matplotlib/pyplot.py:516: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %%
plt.figure()
j=0
for i, group in facebook_viz.groupby('Agency'):
    j = j+1
    if j <7:
        x = group.index
        y = group["Likes/Followers/Visits/Downloads"]
        plt.plot_date(x,y,label=str(i))
        plt.legend(bbox_to_anchor=(1.05, 1),ncol=1, loc=2, borderaxespad=0.)
        plt.xticks(rotation=45)
plt.xlim()
plt.xlabel("Time")
plt.ylabel("counts")
plt.title("Plot for timeseries data from 311 to City Store")
    #group.plot(x=group.index, y='Likes/Followers/Visits/Downloads', title=str(i),kind=scatter)
